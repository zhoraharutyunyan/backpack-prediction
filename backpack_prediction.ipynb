# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_train_extra = pd.read_csv('training_extra.csv')
df_sub = pd.read_csv('sample_submission.csv')

# %%
df_train
# Out:
#             id         Brand Material    Size  Compartments  \
# 0            0      Jansport  Leather  Medium           7.0
# 1            1      Jansport   Canvas   Small          10.0
# 2            2  Under Armour  Leather   Small           2.0
# 3            3          Nike    Nylon   Small           8.0
# 4            4        Adidas   Canvas  Medium           1.0
# ...        ...           ...      ...     ...           ...
# 299995  299995        Adidas  Leather   Small           9.0
# 299996  299996      Jansport  Leather   Large           6.0
# 299997  299997          Puma   Canvas   Large           9.0
# 299998  299998        Adidas    Nylon   Small           1.0
# 299999  299999  Under Armour   Canvas   Small           2.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                     Yes         No       Tote  Black             11.611723
# 1                     Yes        Yes  Messenger  Green             27.078537
# ...

# %%
df_train_extra
# Out:
#               id         Brand   Material    Size  Compartments  \
# 0         500000  Under Armour     Canvas   Small          10.0
# 1         500001          Puma  Polyester   Small           4.0
# 2         500002      Jansport  Polyester   Small           8.0
# 3         500003          Nike      Nylon   Large           7.0
# 4         500004          Nike    Leather   Large           9.0
# ...          ...           ...        ...     ...           ...
# 3694313  4194313          Nike     Canvas     NaN           3.0
# 3694314  4194314          Puma    Leather   Small          10.0
# 3694315  4194315      Jansport     Canvas   Large          10.0
# 3694316  4194316          Puma     Canvas     NaN           2.0
# 3694317  4194317  Under Armour  Polyester  Medium           2.0
#
#         Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                      Yes        Yes       Tote   Blue             23.882052
# ...

# %%
df_train = pd.concat([df_train,df_train_extra])

# %%
df_train
# Out:
#               id         Brand   Material    Size  Compartments  \
# 0              0      Jansport    Leather  Medium           7.0
# 1              1      Jansport     Canvas   Small          10.0
# 2              2  Under Armour    Leather   Small           2.0
# 3              3          Nike      Nylon   Small           8.0
# 4              4        Adidas     Canvas  Medium           1.0
# ...          ...           ...        ...     ...           ...
# 3694313  4194313          Nike     Canvas     NaN           3.0
# 3694314  4194314          Puma    Leather   Small          10.0
# 3694315  4194315      Jansport     Canvas   Large          10.0
# 3694316  4194316          Puma     Canvas     NaN           2.0
# 3694317  4194317  Under Armour  Polyester  Medium           2.0
#
#         Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                      Yes         No       Tote  Black             11.611723
# ...

# %%
df_test
# Out:
#             id         Brand   Material    Size  Compartments  \
# 0       300000          Puma    Leather   Small           2.0
# 1       300001          Nike     Canvas  Medium           7.0
# 2       300002        Adidas     Canvas   Large           9.0
# 3       300003        Adidas      Nylon   Large           1.0
# 4       300004           NaN      Nylon   Large           2.0
# ...        ...           ...        ...     ...           ...
# 199995  499995        Adidas     Canvas   Large           2.0
# 199996  499996          Nike  Polyester   Small           9.0
# 199997  499997      Jansport      Nylon   Small           9.0
# 199998  499998          Puma      Nylon   Large          10.0
# 199999  499999  Under Armour    Leather  Medium           8.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)
# 0                      No         No       Tote  Green             20.671147
# ...

# %%
df_train = df_train.drop('id', axis=1)
df_test = df_test.drop('id', axis=1)

# %%
df_train.isna().sum()[df_train.isna().sum() != 0].sort_values()[::-1] * 100 / len(df_train)
# Out:
# Series([], dtype: float64)

# %%
df_train['Color'].value_counts()
# Out:
# Color
# Pink     688257
# Gray     666110
# Blue     638485
# Red      630215
# Black    620610
# Green    617024
# Name: count, dtype: int64

# %%
df_train['Color'] = df_train['Color'].fillna(np.random.choice(a=['Pink','Gray','Blue','Red','Black','Green'],p=[0.17,0.17,0.17,0.17,0.16,0.16]))
df_test['Color'] = df_test['Color'].fillna(np.random.choice(a=['Pink','Gray','Blue','Red','Black','Green'],p=[0.17,0.17,0.17,0.17,0.16,0.16]))

# %%
df_train['Brand'].value_counts()
# Out:
# Brand
# Under Armour    801035
# Adidas          797000
# Nike            764407
# Puma            755778
# Jansport        749340
# Name: count, dtype: int64

# %%
df_train['Brand'] = df_train['Brand'].fillna(np.random.choice(a=['Under Armour','Adidas','Nike','Puma','Jansport'],p=[0.20,0.20,0.20,0.20,0.20]))
df_test['Brand'] = df_test['Brand'].fillna(np.random.choice(a=['Under Armour','Adidas','Nike','Puma','Jansport'],p=[0.20,0.20,0.20,0.20,0.20]))

# %%
df_train['Material'].value_counts()
# Out:
# Material
# Polyester    1060882
# Leather       976186
# Nylon         942656
# Canvas        903632
# Name: count, dtype: int64

# %%
df_train['Material'] = df_train['Material'].fillna(np.random.choice(a=['Polyester','Leather','Nylon','Canvas'],p=[0.4,0.2,0.2,0.2]))
df_test['Material'] = df_test['Material'].fillna(np.random.choice(a=['Polyester','Leather','Nylon','Canvas'],p=[0.4,0.2,0.2,0.2]))

# %%
df_train['Style'].value_counts()
# Out:
# Style
# Messenger    1329677
# Tote         1297942
# Backpack     1262519
# Name: count, dtype: int64

# %%
df_train['Style'] = df_train['Style'].fillna(np.random.choice(a=['Messenger','Tote','Backpack'],p=[0.4,0.3,0.3]))
df_test['Style'] = df_test['Style'].fillna(np.random.choice(a=['Messenger','Tote','Backpack'],p=[0.4,0.3,0.3]))

# %%
df_train['Laptop Compartment'].value_counts()
# Out:
# Laptop Compartment
# Yes    1972937
# No     1922848
# Name: count, dtype: int64

# %%
df_train['Laptop Compartment'] = df_train['Laptop Compartment'].fillna(np.random.choice(a=['Yes','No'],p=[0.5,0.5]))
df_test['Laptop Compartment'] = df_test['Laptop Compartment'].fillna(np.random.choice(a=['Yes','No'],p=[0.5,0.5]))

# %%
df_train['Waterproof'].value_counts()
# Out:
# Waterproof
# Yes    1969205
# No     1930789
# Name: count, dtype: int64

# %%
df_train['Waterproof'] = df_train['Waterproof'].fillna(np.random.choice(a=['Yes','No'],p=[0.5,0.5]))
df_test['Waterproof'] = df_test['Waterproof'].fillna(np.random.choice(a=['Yes','No'],p=[0.5,0.5]))

# %%
df_train['Size'].value_counts()
# Out:
# Size
# Medium    1354487
# Large     1312295
# Small     1239751
# Name: count, dtype: int64

# %%
df_train['Size'] = df_train['Size'].fillna(np.random.choice(a=['Medium','Large','Small'],p=[0.4,0.3,0.3]))
df_test['Size'] = df_test['Size'].fillna(np.random.choice(a=['Medium','Large','Small'],p=[0.4,0.3,0.3]))

# %%
df_train['Weight Capacity (kg)'].value_counts()
# Out:
# Weight Capacity (kg)
# 5.000000     58087
# 30.000000     2588
# 11.898250     1571
# 14.908437     1559
# 22.898382     1417
#              ...
# 29.013180        1
# 13.554790        1
# 12.926170        1
# 12.571250        1
# 17.749338        1
# Name: count, Length: 1920345, dtype: int64

# %%
df_train['Weight Capacity (kg)'] = df_train['Weight Capacity (kg)'].fillna(df_train['Weight Capacity (kg)'].median())
df_test['Weight Capacity (kg)'] = df_test['Weight Capacity (kg)'].fillna(df_test['Weight Capacity (kg)'].median())

# %%
df_train.isna().sum()
# Out:
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# Price                   0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# dtype: int64

# %%
df_train
# Out:
#          Brand  Material  Size  Compartments  Laptop Compartment  Waterproof  \
# 0            1         1     1           7.0                   1           0
# 1            1         0     2          10.0                   1           1
# 2            4         1     2           2.0                   1           0
# 3            2         2     2           8.0                   1           0
# 4            0         0     1           1.0                   1           1
# ...        ...       ...   ...           ...                 ...         ...
# 3694313      2         0     2           3.0                   1           1
# 3694314      3         1     2          10.0                   1           1
# 3694315      1         0     0          10.0                   0           0
# 3694316      3         0     2           2.0                   0           0
# 3694317      4         3     1           2.0                   1           0
#
# ...

# %%
df_test
# Out:
#         Brand  Material  Size  Compartments  Laptop Compartment  Waterproof  \
# 0           3         1     2           2.0                   0           0
# 1           2         0     1           7.0                   0           1
# 2           0         0     0           9.0                   0           1
# 3           0         2     0           1.0                   1           0
# 4           4         2     0           2.0                   1           1
# ...       ...       ...   ...           ...                 ...         ...
# 199995      0         0     0           2.0                   1           0
# 199996      2         3     2           9.0                   0           1
# 199997      1         2     2           9.0                   0           1
# 199998      3         2     0          10.0                   1           0
# 199999      4         1     1           8.0                   1           1
#
#         Style  Color  Weight Capacity (kg)
# ...

# %%
set(df_test['Brand'].unique()).difference(set(df_train['Brand'].unique()))
# Out:
# set()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_train['Brand'] = label.fit_transform(df_train['Brand'])
df_test['Brand'] = label.transform(df_test['Brand'])

# %%
set(df_test['Material'].unique()).difference(set(df_train['Material'].unique()))
# Out:
# set()

# %%
df_train['Material'] = label.fit_transform(df_train['Material'])
df_test['Material'] = label.transform(df_test['Material'])

# %%
set(df_test['Size'].unique()).difference(set(df_train['Size'].unique()))
# Out:
# set()

# %%
df_train['Size'] = label.fit_transform(df_train['Size'])
df_test['Size'] = label.transform(df_test['Size'])

# %%
set(df_test['Laptop Compartment'].unique()).difference(set(df_train['Laptop Compartment'].unique()))
# Out:
# set()

# %%
df_train['Laptop Compartment'] = label.fit_transform(df_train['Laptop Compartment'])
df_test['Laptop Compartment'] = label.transform(df_test['Laptop Compartment'])

# %%
set(df_test['Waterproof'].unique()).difference(set(df_train['Waterproof'].unique()))
# Out:
# set()

# %%
df_train['Waterproof'] = label.fit_transform(df_train['Waterproof'])
df_test['Waterproof'] = label.transform(df_test['Waterproof'])

# %%
set(df_test['Style'].unique()).difference(set(df_train['Style'].unique()))
# Out:
# set()

# %%
df_train['Style'] = label.fit_transform(df_train['Style'])
df_test['Style'] = label.transform(df_test['Style'])

# %%
set(df_test['Color'].unique()).difference(set(df_train['Color'].unique()))
# Out:
# set()

# %%
df_train['Color'] = label.fit_transform(df_train['Color'])
df_test['Color'] = label.transform(df_test['Color'])

# %%
X_train = df_train.drop("Price", axis=1)
y_train = df_train['Price']

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
df_sub = pd.read_csv('sample_submission.csv')

# %%
df_sub['Price'] = y_pred

# %%
df_sub
# Out:
#             id      Price
# 0       300000  81.714576
# 1       300001  80.737062
# 2       300002  80.042473
# 3       300003  81.189979
# 4       300004  81.187580
# ...        ...        ...
# 199995  499995  80.005004
# 199996  499996  80.377400
# 199997  499997  81.981782
# 199998  499998  82.524924
# 199999  499999  83.080690
#
# [200000 rows x 2 columns]

# %%
df_sub.to_csv('sub.csv', index=False, index_label=False)
